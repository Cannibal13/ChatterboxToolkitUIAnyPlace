# %%
# ChatterboxToolkitUIAnyPlace - Colab Setup
# This notebook sets up the portable version in Google Colab

# !git clone https://github.com/Cannibal13/ChatterboxToolkitUIAnyPlace.git
# !pip install chatterbox-tts
# !pip install gradio==5.31.0 pydub scipy webrtcvad nltk
# !apt install ffmpeg -y
# %cd /content/ChatterboxToolkitUIAnyPlace/

# Download NLTK punkt data for text splitting
import nltk
nltk.download('punkt')

file_path = "ChatterboxToolkitUIAnyPlace.py"

with open(file_path, "r", encoding="utf-8") as f:
    code = f.read()

# Replace launch() with launch(share=True) for Colab tunneling
updated_code = code.replace(
    "demo.queue().launch()",
    "demo.queue().launch(share=True)"
)

# Also fix the script dir for Colab environment
updated_code = updated_code.replace(
    "SCRIPT_DIR = os.path.dirname(os.path.abspath(__file__))",
    "SCRIPT_DIR = '/content/ChatterboxToolkitUIAnyPlace'"
)

with open(file_path, "w", encoding="utf-8") as f:
    f.write(updated_code)

print("✅ Setup complete! Launching ChatterboxToolkitUIAnyPlace with share=True...")

# %%
# %cd /content/ChatterboxToolkitUIAnyPlace/
# !python ChatterboxToolkitUIAnyPlace.py
